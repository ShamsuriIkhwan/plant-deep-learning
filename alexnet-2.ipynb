# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Flatten,Dropout
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.layers import BatchNormalization, Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
train_dir='/kaggle/input/dataset-v3/V3 data/split_dataset_227/train'
valid_dir='/kaggle/input/dataset-v3/V3 data/split_dataset_227/valid'
test_dir='/kaggle/input/dataset-v3/V3 data/split_dataset_227/test'

# %%
batch_size = 32
img_height,img_width = (227,227)
num_classes = 2
EPOCHS = 50

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.4
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 6729 images belonging to 2 classes.

# %%
valid_generator = train_datagen.flow_from_directory(
    directory=valid_dir,
    target_size=(img_height, img_width),
    batch_size=1,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 1281 images belonging to 2 classes.

# %%
test_generator = train_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(img_height, img_width),
    batch_size=1,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 642 images belonging to 2 classes.

# %%
x, y = test_generator.next()
x.shape  # Display to confirm the shape of the input
# Out:
# (1, 227, 227, 3)

# %%
class_names = list(train_generator.class_indices.keys())
print(class_names)
# Out:
# ['Diseased', 'Healthy']

# %%
target_names = ['Diseased', 'Healthy']

# %%
def AlexNet():
    input_layer = Input(shape=train_generator.image_shape)

    # First convolutional layer
    X = Conv2D(filters=96, kernel_size=(11, 11), strides=4, activation='relu', padding="same")(input_layer)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(3, 3), strides=2)(X)

    # Second convolutional layer
    X = Conv2D(filters=256, kernel_size=(5, 5), activation='relu', padding="same")(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(3, 3), strides=2)(X)

    # Third convolutional layer
    X = Conv2D(filters=384, kernel_size=(3, 3), strides=1, activation='relu', padding="same")(X)
    X = BatchNormalization()(X)

    # Fourth convolutional layer
    X = Conv2D(filters=384, kernel_size=(3, 3), strides=1, activation='relu', padding="same")(X)
    X = BatchNormalization()(X)

    # Fifth convolutional layer
    X = Conv2D(filters=256, kernel_size=(3, 3), strides=1, activation='relu', padding="same")(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(3, 3), strides=2)(X)

    # Flattening
    X = Flatten()(X)

    # First fully connected layer
    X = Dense(4096, activation='relu')(X)
    X = Dropout(0.5)(X)

    # Second fully connected layer
    X = Dense(4096, activation='relu')(X)
    X = Dropout(0.5)(X)

    # Output layer
    predictions = Dense(train_generator.num_classes, activation='softmax')(X)

    # Create the model
    model = Model(inputs=input_layer, outputs=predictions, name="AlexNet")
    return model

# %%
model = AlexNet()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv2d (Conv2D)             (None, 57, 57, 96)        34944
#
#  batch_normalization (BatchN  (None, 57, 57, 96)       384
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  batch_normalization_3 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       884992
#
#  batch_normalization_4 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 58,295,042
# Trainable params: 58,292,290
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint

# Custom callback to save the model at specific epochs
class SaveModelAtEpochs(Callback):
    def __init__(self, checkpoint_filepath, save_epochs):
        super(SaveModelAtEpochs, self).__init__()
        self.checkpoint_filepath = checkpoint_filepath
        self.save_epochs = save_epochs

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) in self.save_epochs:
            self.model.save(self.checkpoint_filepath.format(epoch=epoch+1))

# Define the checkpoint filepath for the best model
checkpoint_filepath_best = '/kaggle/working/Alexnet/50epoch.{epoch:02d}-{val_loss:.2f}.h5'

# Create the ModelCheckpoint callback for the best model
checkpoint_best = ModelCheckpoint(
    filepath=checkpoint_filepath_best,
    save_best_only=True,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

# Define the checkpoint filepath and save epochs for the custom callback
checkpoint_filepath_epochs = '/kaggle/working/Alexnet/save_by_epochs/alex_model_{epoch}.h5'
save_epochs = [10, 20, 30, 40, 50]

# Create the custom callback to save the model at specific epochs
custom_checkpoint = SaveModelAtEpochs(checkpoint_filepath_epochs, save_epochs)

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=valid_generator,
    callbacks=[checkpoint_best, custom_checkpoint]
)
# Out:
# Epoch 1/50
# 211/211 [==============================] - ETA: 0s - loss: 2.8763 - accuracy: 0.6133
# Epoch 1: val_accuracy improved from -inf to 0.51366, saving model to /kaggle/working/Alexnet/50epoch.01-3.32.h5
# 211/211 [==============================] - 119s 508ms/step - loss: 2.8763 - accuracy: 0.6133 - val_loss: 3.3213 - val_accuracy: 0.5137
# Epoch 2/50
# 211/211 [==============================] - ETA: 0s - loss: 0.4883 - accuracy: 0.7957
# Epoch 2: val_accuracy improved from 0.51366 to 0.64793, saving model to /kaggle/working/Alexnet/50epoch.02-2.25.h5
# 211/211 [==============================] - 96s 454ms/step - loss: 0.4883 - accuracy: 0.7957 - val_loss: 2.2458 - val_accuracy: 0.6479
# Epoch 3/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3781 - accuracy: 0.8514
# Epoch 3: val_accuracy improved from 0.64793 to 0.68696, saving model to /kaggle/working/Alexnet/50epoch.03-0.80.h5
# 211/211 [==============================] - 95s 450ms/step - loss: 0.3781 - accuracy: 0.8514 - val_loss: 0.8004 - val_accuracy: 0.6870
# Epoch 4/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8665
# Epoch 4: val_accuracy improved from 0.68696 to 0.73224, saving model to /kaggle/working/Alexnet/50epoch.04-0.67.h5
# 211/211 [==============================] - 94s 444ms/step - loss: 0.3473 - accuracy: 0.8665 - val_loss: 0.6718 - val_accuracy: 0.7322
# Epoch 5/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3606 - accuracy: 0.8680
# Epoch 5: val_accuracy improved from 0.73224 to 0.74161, saving model to /kaggle/working/Alexnet/50epoch.05-0.76.h5
# 211/211 [==============================] - 95s 449ms/step - loss: 0.3606 - accuracy: 0.8680 - val_loss: 0.7622 - val_accuracy: 0.7416
# Epoch 6/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8893
# Epoch 6: val_accuracy did not improve from 0.74161
# 211/211 [==============================] - 93s 443ms/step - loss: 0.3175 - accuracy: 0.8893 - val_loss: 2.2500 - val_accuracy: 0.5870
# Epoch 7/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8969
# Epoch 7: val_accuracy improved from 0.74161 to 0.80562, saving model to /kaggle/working/Alexnet/50epoch.07-0.86.h5
# 211/211 [==============================] - 95s 451ms/step - loss: 0.2985 - accuracy: 0.8969 - val_loss: 0.8586 - val_accuracy: 0.8056
# Epoch 8/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.8833
# Epoch 8: val_accuracy did not improve from 0.80562
# 211/211 [==============================] - 95s 451ms/step - loss: 0.3373 - accuracy: 0.8833 - val_loss: 4.3448 - val_accuracy: 0.6792
# Epoch 9/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.8853
# Epoch 9: val_accuracy did not improve from 0.80562
# 211/211 [==============================] - 93s 443ms/step - loss: 0.3187 - accuracy: 0.8853 - val_loss: 2.1025 - val_accuracy: 0.7049
# Epoch 10/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.9038
# Epoch 10: val_accuracy did not improve from 0.80562
# 211/211 [==============================] - 96s 456ms/step - loss: 0.2790 - accuracy: 0.9038 - val_loss: 2.0614 - val_accuracy: 0.7158
# Epoch 11/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.9049
# Epoch 11: val_accuracy did not improve from 0.80562
# 211/211 [==============================] - 93s 443ms/step - loss: 0.2568 - accuracy: 0.9049 - val_loss: 6.1791 - val_accuracy: 0.5144
# Epoch 12/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.9031
# Epoch 12: val_accuracy did not improve from 0.80562
# 211/211 [==============================] - 93s 439ms/step - loss: 0.2689 - accuracy: 0.9031 - val_loss: 1.1751 - val_accuracy: 0.7884
# Epoch 13/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3370 - accuracy: 0.8884
# Epoch 13: val_accuracy improved from 0.80562 to 0.83138, saving model to /kaggle/working/Alexnet/50epoch.13-1.26.h5
# 211/211 [==============================] - 95s 450ms/step - loss: 0.3370 - accuracy: 0.8884 - val_loss: 1.2575 - val_accuracy: 0.8314
# Epoch 14/50
# 211/211 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.8233
# Epoch 14: val_accuracy did not improve from 0.83138
# 211/211 [==============================] - 93s 443ms/step - loss: 0.4716 - accuracy: 0.8233 - val_loss: 1.8009 - val_accuracy: 0.5347
# Epoch 15/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.8652
# Epoch 15: val_accuracy did not improve from 0.83138
# 211/211 [==============================] - 93s 439ms/step - loss: 0.3418 - accuracy: 0.8652 - val_loss: 1.0377 - val_accuracy: 0.7346
# Epoch 16/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.8894
# Epoch 16: val_accuracy improved from 0.83138 to 0.84699, saving model to /kaggle/working/Alexnet/50epoch.16-0.51.h5
# 211/211 [==============================] - 94s 447ms/step - loss: 0.2955 - accuracy: 0.8894 - val_loss: 0.5067 - val_accuracy: 0.8470
# Epoch 17/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.9025
# Epoch 17: val_accuracy did not improve from 0.84699
# 211/211 [==============================] - 92s 438ms/step - loss: 0.2772 - accuracy: 0.9025 - val_loss: 2.1476 - val_accuracy: 0.7119
# Epoch 18/50
# 211/211 [==============================] - ETA: 0s - loss: 0.4188 - accuracy: 0.8487
# Epoch 18: val_accuracy did not improve from 0.84699
# 211/211 [==============================] - 97s 458ms/step - loss: 0.4188 - accuracy: 0.8487 - val_loss: 1.1622 - val_accuracy: 0.6511
# Epoch 19/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.9003
# Epoch 19: val_accuracy did not improve from 0.84699
# 211/211 [==============================] - 93s 444ms/step - loss: 0.2869 - accuracy: 0.9003 - val_loss: 0.4521 - val_accuracy: 0.8298
# Epoch 20/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9184
# Epoch 20: val_accuracy did not improve from 0.84699
# 211/211 [==============================] - 95s 449ms/step - loss: 0.2317 - accuracy: 0.9184 - val_loss: 0.6418 - val_accuracy: 0.8353
# Epoch 21/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.9272
# Epoch 21: val_accuracy did not improve from 0.84699
# 211/211 [==============================] - 94s 443ms/step - loss: 0.2457 - accuracy: 0.9272 - val_loss: 1.7280 - val_accuracy: 0.8173
# Epoch 22/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3660 - accuracy: 0.8753
# Epoch 22: val_accuracy did not improve from 0.84699
# 211/211 [==============================] - 92s 436ms/step - loss: 0.3660 - accuracy: 0.8753 - val_loss: 2.9967 - val_accuracy: 0.6635
# Epoch 23/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9184
# Epoch 23: val_accuracy did not improve from 0.84699
# 211/211 [==============================] - 93s 441ms/step - loss: 0.2447 - accuracy: 0.9184 - val_loss: 1.0276 - val_accuracy: 0.7104
# Epoch 24/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9263
# Epoch 24: val_accuracy did not improve from 0.84699
# 211/211 [==============================] - 97s 458ms/step - loss: 0.2222 - accuracy: 0.9263 - val_loss: 1.4510 - val_accuracy: 0.7213
# Epoch 25/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2113 - accuracy: 0.9276
# Epoch 25: val_accuracy improved from 0.84699 to 0.85714, saving model to /kaggle/working/Alexnet/50epoch.25-0.66.h5
# 211/211 [==============================] - 95s 451ms/step - loss: 0.2113 - accuracy: 0.9276 - val_loss: 0.6603 - val_accuracy: 0.8571
# Epoch 26/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9333
# Epoch 26: val_accuracy did not improve from 0.85714
# 211/211 [==============================] - 96s 453ms/step - loss: 0.2081 - accuracy: 0.9333 - val_loss: 3.5339 - val_accuracy: 0.6292
# Epoch 27/50
# 211/211 [==============================] - ETA: 0s - loss: 0.4962 - accuracy: 0.8429
# Epoch 27: val_accuracy did not improve from 0.85714
# 211/211 [==============================] - 96s 455ms/step - loss: 0.4962 - accuracy: 0.8429 - val_loss: 0.5499 - val_accuracy: 0.8361
# Epoch 28/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9226
# Epoch 28: val_accuracy did not improve from 0.85714
# 211/211 [==============================] - 98s 465ms/step - loss: 0.2260 - accuracy: 0.9226 - val_loss: 2.7992 - val_accuracy: 0.5472
# Epoch 29/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9386
# Epoch 29: val_accuracy did not improve from 0.85714
# 211/211 [==============================] - 93s 441ms/step - loss: 0.1980 - accuracy: 0.9386 - val_loss: 1.2676 - val_accuracy: 0.6838
# Epoch 30/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1738 - accuracy: 0.9419
# Epoch 30: val_accuracy improved from 0.85714 to 0.86183, saving model to /kaggle/working/Alexnet/50epoch.30-0.73.h5
# 211/211 [==============================] - 96s 456ms/step - loss: 0.1738 - accuracy: 0.9419 - val_loss: 0.7279 - val_accuracy: 0.8618
# Epoch 31/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.9441
# Epoch 31: val_accuracy did not improve from 0.86183
# 211/211 [==============================] - 95s 445ms/step - loss: 0.1771 - accuracy: 0.9441 - val_loss: 0.7612 - val_accuracy: 0.8165
# Epoch 32/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9544
# Epoch 32: val_accuracy did not improve from 0.86183
# 211/211 [==============================] - 94s 445ms/step - loss: 0.1463 - accuracy: 0.9544 - val_loss: 1.6521 - val_accuracy: 0.7892
# Epoch 33/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9462
# Epoch 33: val_accuracy did not improve from 0.86183
# 211/211 [==============================] - 92s 437ms/step - loss: 0.1698 - accuracy: 0.9462 - val_loss: 2.0990 - val_accuracy: 0.7744
# Epoch 34/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9596
# Epoch 34: val_accuracy did not improve from 0.86183
# 211/211 [==============================] - 93s 442ms/step - loss: 0.1185 - accuracy: 0.9596 - val_loss: 3.1008 - val_accuracy: 0.7705
# Epoch 35/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9568
# Epoch 35: val_accuracy improved from 0.86183 to 0.86261, saving model to /kaggle/working/Alexnet/50epoch.35-0.84.h5
# 211/211 [==============================] - 97s 459ms/step - loss: 0.1358 - accuracy: 0.9568 - val_loss: 0.8420 - val_accuracy: 0.8626
# Epoch 36/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9548
# Epoch 36: val_accuracy did not improve from 0.86261
# 211/211 [==============================] - 94s 448ms/step - loss: 0.1528 - accuracy: 0.9548 - val_loss: 0.9505 - val_accuracy: 0.7963
# Epoch 37/50
# 211/211 [==============================] - ETA: 0s - loss: 1.1656 - accuracy: 0.7451
# Epoch 37: val_accuracy did not improve from 0.86261
# 211/211 [==============================] - 94s 443ms/step - loss: 1.1656 - accuracy: 0.7451 - val_loss: 0.6998 - val_accuracy: 0.7104
# Epoch 38/50
# 211/211 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.8877
# Epoch 38: val_accuracy did not improve from 0.86261
# 211/211 [==============================] - 92s 437ms/step - loss: 0.3020 - accuracy: 0.8877 - val_loss: 0.4272 - val_accuracy: 0.8509
# Epoch 39/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9230
# Epoch 39: val_accuracy did not improve from 0.86261
# 211/211 [==============================] - 93s 443ms/step - loss: 0.2102 - accuracy: 0.9230 - val_loss: 0.9692 - val_accuracy: 0.8142
# Epoch 40/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2089 - accuracy: 0.9287
# Epoch 40: val_accuracy did not improve from 0.86261
# 211/211 [==============================] - 96s 454ms/step - loss: 0.2089 - accuracy: 0.9287 - val_loss: 0.4466 - val_accuracy: 0.8337
# Epoch 41/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9336
# Epoch 41: val_accuracy did not improve from 0.86261
# 211/211 [==============================] - 92s 438ms/step - loss: 0.1872 - accuracy: 0.9336 - val_loss: 0.5765 - val_accuracy: 0.8470
# Epoch 42/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1787 - accuracy: 0.9407
# Epoch 42: val_accuracy did not improve from 0.86261
# 211/211 [==============================] - 93s 439ms/step - loss: 0.1787 - accuracy: 0.9407 - val_loss: 0.6915 - val_accuracy: 0.7151
# Epoch 43/50
# 211/211 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.9269
# Epoch 43: val_accuracy did not improve from 0.86261
# 211/211 [==============================] - 94s 444ms/step - loss: 0.2254 - accuracy: 0.9269 - val_loss: 0.4422 - val_accuracy: 0.8228
# Epoch 44/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9462
# Epoch 44: val_accuracy improved from 0.86261 to 0.87510, saving model to /kaggle/working/Alexnet/50epoch.44-0.37.h5
# 211/211 [==============================] - 96s 455ms/step - loss: 0.1689 - accuracy: 0.9462 - val_loss: 0.3693 - val_accuracy: 0.8751
# Epoch 45/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9542
# Epoch 45: val_accuracy did not improve from 0.87510
# 211/211 [==============================] - 94s 448ms/step - loss: 0.1306 - accuracy: 0.9542 - val_loss: 3.4808 - val_accuracy: 0.7627
# Epoch 46/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.9493
# Epoch 46: val_accuracy did not improve from 0.87510
# 211/211 [==============================] - 94s 443ms/step - loss: 0.1628 - accuracy: 0.9493 - val_loss: 1.4247 - val_accuracy: 0.6846
# Epoch 47/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9414
# Epoch 47: val_accuracy did not improve from 0.87510
# 211/211 [==============================] - 95s 451ms/step - loss: 0.1744 - accuracy: 0.9414 - val_loss: 0.8072 - val_accuracy: 0.8548
# Epoch 48/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9642
# Epoch 48: val_accuracy did not improve from 0.87510
# 211/211 [==============================] - 93s 439ms/step - loss: 0.1088 - accuracy: 0.9642 - val_loss: 0.8460 - val_accuracy: 0.7994
# Epoch 49/50
# 211/211 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9712
# Epoch 49: val_accuracy did not improve from 0.87510
# 211/211 [==============================] - 94s 447ms/step - loss: 0.0911 - accuracy: 0.9712 - val_loss: 2.2772 - val_accuracy: 0.7588
# Epoch 50/50
# 211/211 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9579
# Epoch 50: val_accuracy did not improve from 0.87510
# 211/211 [==============================] - 98s 464ms/step - loss: 0.1467 - accuracy: 0.9579 - val_loss: 0.7395 - val_accuracy: 0.8595

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

# Plot Training Accuracy and Validation Accuracy
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('AlexNet Training Accuracy VS Validation Accuracy')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')
axs[0].legend(['Training', 'Validation'])

# Plot Training Loss and Validation Loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('AlexNet Training Loss VS Validation Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].legend(['Training', 'Validation'])

plt.tight_layout()
plt.show()

# %%
import glob
# Loading the best model
saved_models_dir = '/kaggle/working/Alexnet/'
saved_model_files = glob.glob(os.path.join(saved_models_dir, '*.h5'))
saved_model_files.sort()
best_model_file = saved_model_files[-1]
best_model = tf.keras.models.load_model(best_model_file)

# Saving the best model with a different name
best_model.save('/kaggle/working/Alexnet/Saved_Model/Best_AlexNet.h5')

# %%
# Evaluating the best model on the validation set
test_loss, test_acc = best_model.evaluate(valid_generator, verbose = 2)
print('\nVal_accuracy: ', test_acc)
print('\nVal_loss: ', test_loss)
# Out:
# 1281/1281 - 17s - loss: 0.3812 - accuracy: 0.8790 - 17s/epoch - 13ms/step
#
# Val_accuracy:  0.8790007829666138
#
# Val_loss:  0.38124987483024597

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

print("for best Alex model")
model = tf.keras.models.load_model('/kaggle/working/Alexnet/Saved_Model/Best_AlexNet.h5')

filenames = test_generator.filenames
nb_samples = len(test_generator)

y_prob = []
y_act = []

test_generator.reset()
for _ in range(nb_samples):
    X_test, Y_test = test_generator.next()
    y_prob.append(model.predict(X_test))
    y_act.append(Y_test)

predicted_class = [list(train_generator.class_indices.keys())[i.argmax()] for i in y_prob]
actual_class = [list(train_generator.class_indices.keys())[i.argmax()] for i in y_act]

out_df = pd.DataFrame(np.vstack([predicted_class, actual_class]).T, columns=['predicted_class', 'actual_class'])

confusion_matrix = pd.crosstab(out_df['actual_class'], out_df['predicted_class'], rownames=['Actual'], colnames=['Predicted'])

sn.heatmap(confusion_matrix, cmap='Reds', annot=True, fmt='d')
plt.show()
print('test accuracy :{}'.format((np.diagonal(confusion_matrix).sum()/confusion_matrix.sum().sum()*100)))
# Generate classification report
classification_rep = classification_report(out_df['actual_class'], out_df['predicted_class'], target_names=target_names)

print(classification_rep)
# Out:
# for best Alex model
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# test accuracy :88.00623052959502
#               precision    recall  f1-score   support
#
#     Diseased       0.96      0.79      0.87       320
#      Healthy       0.82      0.97      0.89       322
#
#     accuracy                           0.88       642
#    macro avg       0.89      0.88      0.88       642
# weighted avg       0.89      0.88      0.88       642

# %% [markdown]
# import numpy as np
# import pandas as pd
# from sklearn.metrics import classification_report
#
# # List of saved model filepaths
# saved_model_filepaths = [
#     '/kaggle/working/Alexnet/save_by_epochs/alex_model_10.h5',
#     '/kaggle/working/Alexnet/save_by_epochs/alex_model_20.h5',
#     '/kaggle/working/Alexnet/save_by_epochs/alex_model_30.h5',
#     '/kaggle/working/Alexnet/save_by_epochs/alex_model_40.h5',
#     '/kaggle/working/Alexnet/save_by_epochs/alex_model_50.h5'
# ]
#
# target_names = ['Diseased', 'Healthy']
#
# # Load each saved model and make predictions
# classification_reports = []
# for filepath in saved_model_filepaths:
#     model = keras.models.load_model(filepath)
#
#     y_prob = []
#     y_act = []
#
#     test_generator.reset()
#     for _ in range(nb_samples):
#         X_test, Y_test = test_generator.next()
#         y_prob.append(model.predict(X_test))
#         y_act.append(Y_test)
#
#     predicted_class = [list(train_generator.class_indices.keys())[i.argmax()] for i in y_prob]
#     actual_class = [list(train_generator.class_indices.keys())[i.argmax()] for i in y_act]
#
#     out_df = pd.DataFrame(np.vstack([predicted_class, actual_class]).T, columns=['predicted_class', 'actual_class'])
#
#     classification_rep = classification_report(out_df['actual_class'], out_df['predicted_class'], target_names=target_names)
#     classification_reports.append(classification_rep)
#
# # Print the classification reports for each epoch
# for epoch, classification_rep in enumerate(classification_reports, start=1):
#     print(f"Classification Report for Epoch {epoch}:")
#     print(classification_rep)
#     print()
